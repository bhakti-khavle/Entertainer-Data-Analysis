# %%
import pandas as pd

# %%
#eb = Entertainer - Basic Info
#ebt = Entertainer - Breakthrough Info
#el = Entertainer - Last Work Info

# %% [markdown]
# #Importing First Dataset (Entertainer - Basic Info)

# %%
eb = pd.read_excel("/content/Entertainer - Basic Info.xlsx")

# %%
eb.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
ebt = pd.read_excel("/content/Entertainer - Breakthrough Info.xlsx")

# %%
ebt.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %% [markdown]
# #Now removing 'Entertainer' Column from second dataset

# %%
ebt.drop('Entertainer',inplace=True,axis=1)

# %%
ebt.head()
# Out:
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %% [markdown]
# Importing Third Dataset (Entertainer - Last Work Info)

# %%
el = pd.read_excel("/content/Entertainer - Last work Info.xlsx")

# %%
el.head()
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN

# %% [markdown]
# Now again removing 'Entertainer' Column from second dataset

# %%
el.drop('Entertainer',inplace=True,axis=1)

# %%
el.head()
# Out:
#    Year of Last Major Work (arguable)  Year of Death
# 0                                2016            NaN
# 1                                2016            NaN
# 2                                2014            NaN
# 3                                1989         1989.0
# 4                                2016            NaN

# %% [markdown]
# #Concatinating the first two tables (eb and ebt)

# %%
main1 = pd.concat([eb,ebt],axis=1)

# %%
main1.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %%
main = pd.concat([main1,el],axis=1)

# %%
main.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  \
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922
#
#    Year of Breakthrough/#1 Hit/Award Nomination  \
# 0                                          2008
# 1                                          1999
# 2                                          1967
# 3                                          1934
# 4                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy  \
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# ...

# %% [markdown]
# #Saving this file into excel file

# %%
new_file = "main_data.xlsx"

# %%
main.to_excel(new_file)
